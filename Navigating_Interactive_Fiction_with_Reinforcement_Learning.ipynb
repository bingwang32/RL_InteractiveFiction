# %% [markdown]
# # Navigating Interactive Fiction with Reinforcement Learning
#
# ### Bing Wang
# ##### MSDS631: Reinforcement Learning, Final Project<br>
#
# <img src="images/michelle-ding-QAOtKq8ehcw-unsplash.jpg" width="850">

# %% [markdown]
# ## Research Question

# %% [markdown]
# ## Overview
#
# **What is interactive fiction?**
#
# **Why is this a reinforcement learning problem?**
#
# **What were the tools used in this analysis?**
# Jericho
# FrotzEnv
# Key methods in FrotEnv
#
# **How was reinforcement learning used in this project?**

# %% [markdown]
# ### RL problem setup:
#
# States: Text at each step<br>
# Actions: Sampled text (for Detective, either cardinal direction or [verb][noun] generally)

# %% [markdown]
# Deterministic (same state and action always leads to the same value)<br>
# Model-free (don't know all states/available actions)<br>
# Fully observable (we know what state we're in)<br>
# TD updates (update for each state, not full episode)<br>
# Terminal/finite (game will end eventually)<br>
# History may or may not matter; Markov property almost holds

# %% [markdown]
# ## Imports and initializations
#
# We will be training our agent on the game *Detective* by Matt Barringer, a film-noir-esque detective mystery included in [Jericho's set of supported interactive fiction stories.](https://jericho-py.readthedocs.io/en/latest/tutorial_quick.html#acquire-games) I chose this game as an initial story to test out training a reinforcement learning agent because it seemed like a shorter, *terminal* game, with a *limited set of actions* for each stage and the game overall.
#
# Let's read in our story file into Jericho's FrotzEnv environment, and initialize our Agent on that. You can find my Agent class in my repo [here](https://github.com/bingwang32/RL_InteractiveFiction/blob/master/agent.py).

# %%
from utils import *
from agent import *

# %%
story_file = "z-machine-games-master/jericho-game-suite/detective.z5"

# %%
agent = Agent(FrotzEnv(story_file))

# %% [markdown]
# ## Demo of game
#
# ##### Human mode
#
# Here is a human-playable demo of the game. At each step, the demo will print a text description of the story at that step (the state). You will be offered a set of likely valid steps corresponding to the text (as generated by Jericho's natural language processing (NLP) capabilities), and will have the ability to type in one of those options or text of your own choice in the input. *Type in "I quit" to exit the game at any point.*
#
# I have included a short playthrough of my own below; feel free to refresh the cell and do a playthrough of your own!

# %%
agent.demo_game("human")
# Out:
# Welcome! Enter "I quit" at any point to exit the game.
#
# [Type "help" for more information about this version]  Detective By Matt Barringer. Ported by Stuart Moore. Stuart_Moore@my-deja.com Release 1 / Serial number 000715 / Inform v6.21 Library 6/10 SD  << Chief's office >> You are standing in the Chief's office. He is telling you "The Mayor was murdered yeaterday night at 12:03 am. I want you to solve it before we get any bad publicity or the FBI has to come in. "Yessir!" You reply. He hands you a sheet of paper. Once you have read it, go north or west.  You can see a piece of white paper here.  [Your score has just gone up by ten points.]
# Choose one of the following valid moves, or type in something else: ['east', 'take paper', 'west', 'north'] north
#
# << Outside >> You are outside in the cold. To the east is a dead end. To the west is the rest of the street. Papers are blowing around. It's amazingly cold for this time of year.
# Choose one of the following valid moves, or type in something else: ['north', 'west'] west
#
# << Outside >> You are still on the streets. To the north is a restraunt where the mayor ate often. To the east is the Mayor's home.  [Your score has just gone up by ten points.]
# Choose one of the following valid moves, or type in something else: ['west', 'north', 'east'] I quit
#
# Thanks for playing! Your final score was: 20

# %% [markdown]
# ##### Walkthrough mode
#
# In walkthrough mode, you can play through the game making the optimal choices of actions at each state, such that you get the highest possible score.

# %%
print(f'Maximum possible score in game: {agent.game.get_max_score()}')
# Out:
# Maximum possible score in game: 360

# %%
agent.demo_game("walkthrough")
# Out:
# Iteration 0
# State: [Type "help" for more information about this version]  Detective By Matt Barringer. Ported by Stuart Moore. Stuart_Moore@my-deja.com Release 1 / Serial number 000715 / Inform v6.21 Library 6/10 SD  << Chief's office >> You are standing in the Chief's office. He is telling you "The Mayor was murdered yeaterday night at 12:03 am. I want you to solve it before we get any bad publicity or the FBI has to come in. "Yessir!" You reply. He hands you a sheet of paper. Once you have read it, go north or west.  You can see a piece of white paper here.  [Your score has just gone up by ten points.]
# Action selected: TAKE PAPER
# Total score after step: 20
#
# Iteration 1
# State: Taken.  [Your score has just gone up by ten points.]
# Action selected: READ PAPER
# Total score after step: 20
#
# Iteration 2
# State: CONFIDENTIAL: Detective was created by Matt Barringer. He has worked hard on this so you better enjoy it. I did have fun making it though. But I'd REALLY appreciate it if you were kind enough to send a postcard or... dare I even say it?... money... to: Matt Barringer 325 Olive Ave Piedmont CA 94611 Just tell me if you like it or not. If you want to talk to me over a BBS call the Ghostbuster Central BBS at (510)208-5657. There is an Exile Games file area. Have fun. I WILL give hints out over the BBS to any of my games.
# Action selected: DROP PAPER
# Total score after step: 20
#
# Iteration 3
# State: Dropped.
# Action selected: INVENTORY
# Total score after step: 20
#
# Iteration 4
# State: You are carrying nothing.
# Action selected: W
# Total score after step: 20
#
# Iteration 5
# State: << Closet >> You are in a closet. There is a gun on the floor. Better get it. To exit, go east.  You can see a small black pistol here.
# Action selected: TAKE GUN
# Total score after step: 30
#
# Iteration 6
# State: Taken.  [Your score has just gone up by ten points.]
# Action selected: E
# Total score after step: 30
#
# Iteration 7
# State: << Chief's office >> You are standing in the Chief's office. He is telling you "The Mayor was murdered yeaterday night at 12:03 am. I want you to solve it before we get any bad publicity or the FBI has to come in. "Yessir!" You reply. He hands you a sheet of paper. Once you have read it, go north or west.  You can see a piece of white paper here.
# Action selected: N
# Total score after step: 30
#
# Iteration 8
# State: << Outside >> You are outside in the cold. To the east is a dead end. To the west is the rest of the street. Papers are blowing around. It's amazingly cold for this time of year.
# Action selected: W
# Total score after step: 40
#
# Iteration 9
# State: << Outside >> You are still on the streets. To the north is a restraunt where the mayor ate often. To the east is the Mayor's home.  [Your score has just gone up by ten points.]
# Action selected: E
# Total score after step: 50
#
# Iteration 10
# State: << Mayor's house >> You are in the house, at the scene of the crime. You enter and flash your badge before a cop. He admits you. To the north is the upstairs. To the east is the living room and to the west is the dining room.  [Your score has just gone up by ten points.]
# Action selected: E
# Total score after step: 50
#
# Iteration 11
# State: << Living room >> You are standing in the living room. You see a battered piece of wood. You wonder "Should I pick this thing up?". Well, whether you do or don't the only way out of the room is back west.  You can see a wooden wood here.
# Action selected: TAKE WOOD
# Total score after step: 60
#
# Iteration 12
# State: Taken.  [Your score has just gone up by ten points.]
# Action selected: W
# Total score after step: 60
#
# Iteration 13
# State: << Mayor's house >> You are in the house, at the scene of the crime. You enter and flash your badge before a cop. He admits you. To the north is the upstairs. To the east is the living room and to the west is the dining room.
# Action selected: W
# Total score after step: 60
#
# Iteration 14
# State: << Dining room >> You are in the dining room. You look around and see a note on the table. You can go back east.  You can see a paper note here.
# Action selected: TAKE NOTE
# Total score after step: 70
#
# Iteration 15
# State: Taken.  [Your score has just gone up by ten points.]
# Action selected: READ NOTE
# Total score after step: 70
#
# Iteration 16
# State: The note was written on a computer obviously this murder was planned and it says: We have acclaimed Justice! The Justice of the future! Our next hit is the governer! You CAN'T STOP US! The note sounds like the killers are a group and that they are vigilantes (look it up). You are now getting a bit worried.
# Action selected: E
# Total score after step: 70
#
# Iteration 17
# State: << Mayor's house >> You are in the house, at the scene of the crime. You enter and flash your badge before a cop. He admits you. To the north is the upstairs. To the east is the living room and to the west is the dining room.
# Action selected: N
# Total score after step: 80
#
# Iteration 18
# State: << Upstairs hallway >> You are in the hallway of the large house of the mayor. It is an amazingly large house. You can go north, south, east or west.  [Your score has just gone up by ten points.]
# Action selected: N
# Total score after step: 80
#
# Iteration 19
# State: << Hallway >> You are at the end of the hallway. To the north is a room, while to the west is the rest of the hallway.
# Action selected: W
# Total score after step: 80
#
# Iteration 20
# State: << Hallway >> You are in the hallway. To the north is more hallway, and to the east is a door marked "Guests".
# Action selected: N
# Total score after step: 80
#
# Iteration 21
# State: << Hallway >> You are STILL in the hallway. There is EVEN MORE hallway to the north, and a room to the west and a room to the east of you.
# Action selected: N
# Total score after step: 80
#
# Iteration 22
# State: << Hallway >> You are still in the hallway. You can go north to where there is a police officer who will let you outside, or you can go east or west.
# Action selected: W
# Total score after step: 90
#
# Iteration 23
# State: << Bedroom >> You are in the bedroom. You noticed that there was a guard guarding the stairs to the 3rd story, because there is remodelling going on there. You see nothing of importance. Go east.  [Your score has just gone up by ten points.]
# Action selected: E
# Total score after step: 90
#
# Iteration 24
# State: << Hallway >> You are still in the hallway. You can go north to where there is a police officer who will let you outside, or you can go east or west.
# Action selected: N
# Total score after step: 100
#
# Iteration 25
# State: << Outside >> You pass the guard. He nods at you. You are now outside standing on the street. You can go north and east, your choice. To the north is more of the street, and to the east is a video store.  [Your score has just gone up by ten points.]
# Action selected: E
# Total score after step: 100
#
# Iteration 26
# State: << Video Store >> You are in a video store called Brickbuster Video. There are about 3,000 videos here. You can go north, or east.
# Action selected: E
# Total score after step: 110
#
# Iteration 27
# State: << Video Store >> You are still in the video store. You can go north, or east.  [Your score has just gone up by ten points.]
# Action selected: E
# Total score after step: 110
#
# Iteration 28
# State: << Outside >> You are outside. You can go north, south, east or west.
# Action selected: S
# Total score after step: 110
#
# Iteration 29
# State: << McDonalds >> You are in a McDonalds. You pay the guy behind the counter. Now there is a hamburger there. When you have picked it up, go north.  You can see a food hamburger here.
# Action selected: TAKE HAMBURGER
# Total score after step: 120
#
# Iteration 30
# State: Taken.  [Your score has just gone up by ten points.]
# Action selected: N
# Total score after step: 120
#
# Iteration 31
# State: << Outside >> You are outside. You can go north, south, east or west.
# Action selected: N
# Total score after step: 130
#
# Iteration 32
# State: << Outside >> You are still outside. You hit a dead end, then notice that you can go east only.  [Your score has just gone up by ten points.]
# Action selected: E
# Total score after step: 140
#
# Iteration 33
# State: << Music Store >> You are in a music store. You ask the man behind the counter if he knew any information. "Uhh... nope! But the guy back there might be able ta help." You politly thank him and head to the back. You can only go north.  [Your score has just gone up by ten points.]
# Action selected: N
# Total score after step: 150
#
# Iteration 34
# State: << Back of Music Store >> You are in the back of the music store. You ask the guy who's looking at the cool tapes. He looks up at you. "Duh.. no... don't t'ink so... lemme see..." You decide that he's no help. To the west there is a dazed looking man and to the north there is an exit.  [Your score has just gone up by ten points.]
# Action selected: N
# Total score after step: 160
#
# Iteration 35
# State: << Alley >> You are in an alley. A drunken man stagers up to you and says "Boycott FDR! <HICKUP>.". You just walk away. You can go north, east or west. Your call.  [Your score has just gone up by ten points.]
# Action selected: N
# Total score after step: 170
#
# Iteration 36
# State: << Police Station >> You are in the 3rd precinct police station. This isn't your station. You get admitance from the guy at the desk and go to the holding cells. You ask each offender if they know anything. You promise a lighter sentence for the ones who help. But one guy really sets you straight. "I got caught wit' t'ree ounces o' crack. I'm supposed to get 20 years but I'll be out in 2. You can't make me talk cuz it don't matter to me. If I squeal, da guys who did it are gonna come lookin' for me. I know but I ain't gonna tell ya. Now git outta my face.". You are surprised but used to it. You can go north to the outside, south to go back to the alley and west or east to talk to more guys.  [Your score has just gone up by ten points.]
# Action selected: N
# Total score after step: 180
#
# Iteration 37
# State: << Outside >> You are outside. it's bitter cold and you pull your jacket around yourself. To the north is a nice, warm Holiday Inn hotel, where the killer is rumoured to be staying. Or you could go to his favourite hang out, the Wall, to the west, or to the east is the place where he is supposed to be working, the Doughnut King.  [Your score has just gone up by ten points.]
# Action selected: E
# Total score after step: 190
#
# Iteration 38
# State: << Doughnut King >> You are in the Doughnut King, where the greasiest doughnuts on earth reside. He isn't here, no one seems to be for that matter, so you should go west.  [Your score has just gone up by ten points.]
# Action selected: W
# Total score after step: 190
#
# Iteration 39
# State: << Outside >> You are outside. it's bitter cold and you pull your jacket around yourself. To the north is a nice, warm Holiday Inn hotel, where the killer is rumoured to be staying. Or you could go to his favourite hang out, the Wall, to the west, or to the east is the place where he is supposed to be working, the Doughnut King.
# Action selected: W
# Total score after step: 200
#
# Iteration 40
# State: << The Wall >> You don't see him here. You ought to go east.  [Your score has just gone up by ten points.]
# Action selected: E
# Total score after step: 200
#
# Iteration 41
# State: << Outside >> You are outside. it's bitter cold and you pull your jacket around yourself. To the north is a nice, warm Holiday Inn hotel, where the killer is rumoured to be staying. Or you could go to his favourite hang out, the Wall, to the west, or to the east is the place where he is supposed to be working, the Doughnut King.
# Action selected: N
# Total score after step: 210
#
# Iteration 42
# State: << Holiday Inn >> You are in the Holiday Inn registration room. You talk to some suspicious guys, but they don't talk until you hold your gun to their side. "Alright! Alright! I'll talk! He's on the 15th floor! That's all I can tell ya!" You shove them away. You walk up to the registration desk and show the woman there your badge. She gives you the master ring. You now have access to all of the facilitys on the 15th floor. But the problem is that the 15th floor is the suite level, and there are 30 suites, and 5 pools, 2 saunas and 5 game rooms. Big problem! Well, you have all night. You get a picture of all on the 15th floor, the people up there have to show their drivers license to be admitted, and the license is secretly xeroxed. You look at them all. Well, better get started. You see one person who stands out. You get his room number from the lady. Room 30. Now you have to find it. To get started, go north.  [Your score has just gone up by ten points.]
# Action selected: W
# Total score after step: 210
#
# Iteration 43
# State: You can't go west from here!  << Holiday Inn >> You are in the Holiday Inn registration room. You talk to some suspicious guys, but they don't talk until you hold your gun to their side. "Alright! Alright! I'll talk! He's on the 15th floor! That's all I can tell ya!" You shove them away. You walk up to the registration desk and show the woman there your badge. She gives you the master ring. You now have access to all of the facilitys on the 15th floor. But the problem is that the 15th floor is the suite level, and there are 30 suites, and 5 pools, 2 saunas and 5 game rooms. Big problem! Well, you have all night. You get a picture of all on the 15th floor, the people up there have to show their drivers license to be admitted, and the license is secretly xeroxed. You look at them all. Well, better get started. You see one person who stands out. You get his room number from the lady. Room 30. Now you have to find it. To get started, go north.
# Action selected: N
# Total score after step: 220
#
# Iteration 44
# State: << Holiday Inn 15th Floor >> You go up the elevator. When you step out, you see the wallpaper is pink, with little flowers on it. You can go east or west.  [Your score has just gone up by ten points.]
# Action selected: W
# Total score after step: 230
#
# Iteration 45
# State: << Hallway >> You are in the hallway. You see many doors... 1... 2... 3... 4... 5... 6... 7... boy, you have a long way to go. You can only go north.  [Your score has just gone up by ten points.]
# Action selected: N
# Total score after step: 240
#
# Iteration 46
# State: << Hallway >> You are still in the hallways. You can go west or east.  [Your score has just gone up by ten points.]
# Action selected: N
# Total score after step: 240
#
# Iteration 47
# State: You can't go north from here!  << Hallway >> You are still in the hallways. You can go west or east.
# Action selected: w
# Total score after step: 250
#
# Iteration 48
# State: << Hallway >> You are in the hallway. You see numbers flash by as you run through the halls. 19... 20... 21... 22... you are getting close! You can only go north.  [Your score has just gone up by ten points.]
# Action selected: n
# Total score after step: 260
#
# Iteration 49
# State: << Hallway >> You are in the hallway. You feel the heat from the sauna to the west, and to the east is a door marked "Pool A". To the north is more hall.  [Your score has just gone up by ten points.]
# Action selected: n
# Total score after step: 360
#
# Iteration 50
# State: << Room # 30 >> You enter room 30... after a harrowing gun battle you conk him on the head and take him in. You get promoted and suddenly, with the "Jurrasic Park" theme song playing in your head, you feel proud to be an American. For special info about Exile Games, and to leave this darned game, go up.  [Your score has just gone up by one hundred points.]
# Action selected: up
# Total score after step: 360
# 360

# %%
print(f'Final score in walkthrough playthrough: {agent.game.get_score()}')
# Out:
# Final score in walkthrough playthrough: 360

# %% [markdown]
# ##### Random mode
#
# We can also use the agent to demo a playthrough of the game where the action at every state is chosen randomly from the set of available actions. We will use this functionality below to simulate random performance over many iterations, and calculate a baseline level of performance for the agent to beat.

# %%
agent.demo_game("random")
# Out:
# Iteration 0
# State: [Type "help" for more information about this version]  Detective By Matt Barringer. Ported by Stuart Moore. Stuart_Moore@my-deja.com Release 1 / Serial number 000715 / Inform v6.21 Library 6/10 SD  << Chief's office >> You are standing in the Chief's office. He is telling you "The Mayor was murdered yeaterday night at 12:03 am. I want you to solve it before we get any bad publicity or the FBI has to come in. "Yessir!" You reply. He hands you a sheet of paper. Once you have read it, go north or west.  You can see a piece of white paper here.  [Your score has just gone up by ten points.]
# Action selected: east
# Total score after step: 10
#
# Iteration 1
# State: You can't go east from here!  << Chief's office >> You are standing in the Chief's office. He is telling you "The Mayor was murdered yeaterday night at 12:03 am. I want you to solve it before we get any bad publicity or the FBI has to come in. "Yessir!" You reply. He hands you a sheet of paper. Once you have read it, go north or west.  You can see a piece of white paper here.
# Action selected: north
# Total score after step: 10
#
# Iteration 2
# State: << Outside >> You are outside in the cold. To the east is a dead end. To the west is the rest of the street. Papers are blowing around. It's amazingly cold for this time of year.
# Action selected: west
# Total score after step: 20
#
# Iteration 3
# State: << Outside >> You are still on the streets. To the north is a restraunt where the mayor ate often. To the east is the Mayor's home.  [Your score has just gone up by ten points.]
# Action selected: east
# Total score after step: 30
#
# Iteration 4
# State: << Mayor's house >> You are in the house, at the scene of the crime. You enter and flash your badge before a cop. He admits you. To the north is the upstairs. To the east is the living room and to the west is the dining room.  [Your score has just gone up by ten points.]
# Action selected: north
# Total score after step: 40
#
# Iteration 5
# State: << Upstairs hallway >> You are in the hallway of the large house of the mayor. It is an amazingly large house. You can go north, south, east or west.  [Your score has just gone up by ten points.]
# Action selected: west
# Total score after step: 40
#
# Iteration 6
# State: << Closet >> You are in a closet. The closet is of the walk in variety, with about thirty pairs of tennis shoes, ten pairs of heels and about ninety coats and shirts. You start to get claustrophobia. Better get out.
# Action selected: north
# Total score after step: 40
#
# Iteration 7
# State: You can't go north from here!  << Closet >> You are in a closet. The closet is of the walk in variety, with about thirty pairs of tennis shoes, ten pairs of heels and about ninety coats and shirts. You start to get claustrophobia. Better get out.
# Action selected: north
# Total score after step: 40
#
# Iteration 8
# State: You can't go north from here!  << Closet >> You are in a closet. The closet is of the walk in variety, with about thirty pairs of tennis shoes, ten pairs of heels and about ninety coats and shirts. You start to get claustrophobia. Better get out.
# Action selected: north
# Total score after step: 40
#
# Iteration 9
# State: You can't go north from here!  << Closet >> You are in a closet. The closet is of the walk in variety, with about thirty pairs of tennis shoes, ten pairs of heels and about ninety coats and shirts. You start to get claustrophobia. Better get out.
# Action selected: north
# Total score after step: 40
#
# Iteration 10
# State: You can't go north from here!  << Closet >> You are in a closet. The closet is of the walk in variety, with about thirty pairs of tennis shoes, ten pairs of heels and about ninety coats and shirts. You start to get claustrophobia. Better get out.
# Action selected: north
# Total score after step: 40
#
# Iteration 11
# State: You can't go north from here!  << Closet >> You are in a closet. The closet is of the walk in variety, with about thirty pairs of tennis shoes, ten pairs of heels and about ninety coats and shirts. You start to get claustrophobia. Better get out.
# Action selected: east
# Total score after step: 40
#
# Iteration 12
# State: << Upstairs hallway >> You are in the hallway of the large house of the mayor. It is an amazingly large house. You can go north, south, east or west.
# Action selected: get up
# Total score after step: 40
#
# Iteration 13
# State: You can't go out from here!  << Upstairs hallway >> You are in the hallway of the large house of the mayor. It is an amazingly large house. You can go north, south, east or west.
# Action selected: west
# Total score after step: 40
#
# Iteration 14
# State: << Closet >> You are in a closet. The closet is of the walk in variety, with about thirty pairs of tennis shoes, ten pairs of heels and about ninety coats and shirts. You start to get claustrophobia. Better get out.
# Action selected: north
# Total score after step: 40
#
# Iteration 15
# State: You can't go north from here!  << Closet >> You are in a closet. The closet is of the walk in variety, with about thirty pairs of tennis shoes, ten pairs of heels and about ninety coats and shirts. You start to get claustrophobia. Better get out.
# Action selected: north
# Total score after step: 40
#
# Iteration 16
# State: You can't go north from here!  << Closet >> You are in a closet. The closet is of the walk in variety, with about thirty pairs of tennis shoes, ten pairs of heels and about ninety coats and shirts. You start to get claustrophobia. Better get out.
# Action selected: east
# Total score after step: 40
#
# Iteration 17
# State: << Upstairs hallway >> You are in the hallway of the large house of the mayor. It is an amazingly large house. You can go north, south, east or west.
# Action selected: south
# Total score after step: 40
#
# Iteration 18
# State: << Mayor's house >> You are in the house, at the scene of the crime. You enter and flash your badge before a cop. He admits you. To the north is the upstairs. To the east is the living room and to the west is the dining room.
# Action selected: north
# Total score after step: 40
#
# Iteration 19
# State: << Upstairs hallway >> You are in the hallway of the large house of the mayor. It is an amazingly large house. You can go north, south, east or west.
# Action selected: east
# Total score after step: 40
#
# Iteration 20
# State: << Bathroom >> You are in the first bathroom, out of the 5 there is. You notice that it is almost as big as your apartment. You see a knife on the floor here.
# Action selected: north
# Total score after step: 40
#
# Iteration 21
# State: You can't go north from here!  << Bathroom >> You are in the first bathroom, out of the 5 there is. You notice that it is almost as big as your apartment. You see a knife on the floor here.
# Action selected: north
# Total score after step: 40
#
# Iteration 22
# State: You can't go north from here!  << Bathroom >> You are in the first bathroom, out of the 5 there is. You notice that it is almost as big as your apartment. You see a knife on the floor here.
# Action selected: west
# Total score after step: 40
#
# Iteration 23
# State: << Upstairs hallway >> You are in the hallway of the large house of the mayor. It is an amazingly large house. You can go north, south, east or west.
# Action selected: west
# Total score after step: 40
#
# Iteration 24
# State: << Closet >> You are in a closet. The closet is of the walk in variety, with about thirty pairs of tennis shoes, ten pairs of heels and about ninety coats and shirts. You start to get claustrophobia. Better get out.
# Action selected: north
# Total score after step: 40
#
# Iteration 25
# State: You can't go north from here!  << Closet >> You are in a closet. The closet is of the walk in variety, with about thirty pairs of tennis shoes, ten pairs of heels and about ninety coats and shirts. You start to get claustrophobia. Better get out.
# Action selected: north
# Total score after step: 40
#
# Iteration 26
# State: You can't go north from here!  << Closet >> You are in a closet. The closet is of the walk in variety, with about thirty pairs of tennis shoes, ten pairs of heels and about ninety coats and shirts. You start to get claustrophobia. Better get out.
# Action selected: north
# Total score after step: 40
#
# Iteration 27
# State: You can't go north from here!  << Closet >> You are in a closet. The closet is of the walk in variety, with about thirty pairs of tennis shoes, ten pairs of heels and about ninety coats and shirts. You start to get claustrophobia. Better get out.
# Action selected: east
# Total score after step: 40
#
# Iteration 28
# State: << Upstairs hallway >> You are in the hallway of the large house of the mayor. It is an amazingly large house. You can go north, south, east or west.
# Action selected: north
# Total score after step: 40
#
# Iteration 29
# State: << Hallway >> You are at the end of the hallway. To the north is a room, while to the west is the rest of the hallway.
# Action selected: west
# Total score after step: 40
# Iteration 30
# State: << Hallway >> You are in the hallway. To the north is more hallway, and to the east is a door marked "Guests".
# Action selected: north
# Total score after step: 40
#
# Iteration 31
# State: << Hallway >> You are STILL in the hallway. There is EVEN MORE hallway to the north, and a room to the west and a room to the east of you.
# Action selected: south
# Total score after step: 40
#
# Iteration 32
# State: You can't go south from here!  << Hallway >> You are STILL in the hallway. There is EVEN MORE hallway to the north, and a room to the west and a room to the east of you.
# Action selected: north
# Total score after step: 40
#
# Iteration 33
# State: << Hallway >> You are still in the hallway. You can go north to where there is a police officer who will let you outside, or you can go east or west.
# Action selected: north
# Total score after step: 50
#
# Iteration 34
# State: << Outside >> You pass the guard. He nods at you. You are now outside standing on the street. You can go north and east, your choice. To the north is more of the street, and to the east is a video store.  [Your score has just gone up by ten points.]
# Action selected: east
# Total score after step: 50
#
# Iteration 35
# State: << Video Store >> You are in a video store called Brickbuster Video. There are about 3,000 videos here. You can go north, or east.
# Action selected: west
# Total score after step: 50
#
# Iteration 36
# State: You can't go west from here!  << Video Store >> You are in a video store called Brickbuster Video. There are about 3,000 videos here. You can go north, or east.
# Action selected: west
# Total score after step: 50
#
# Iteration 37
# State: You can't go west from here!  << Video Store >> You are in a video store called Brickbuster Video. There are about 3,000 videos here. You can go north, or east.
# Action selected: west
# Total score after step: 50
#
# Iteration 38
# State: You can't go west from here!  << Video Store >> You are in a video store called Brickbuster Video. There are about 3,000 videos here. You can go north, or east.
# Action selected: north
# Total score after step: 50
#
# Iteration 39
# State: << Backroom >> You are in the backroom of Brickbuster Video. You see a small video on the floor, but you dismiss it as having no potential value to the crime. You can go south.
# Action selected: south
# Total score after step: 50
#
# Iteration 40
# State: << Video Store >> You are in a video store called Brickbuster Video. There are about 3,000 videos here. You can go north, or east.
# Action selected: west
# Total score after step: 50
#
# Iteration 41
# State: You can't go west from here!  << Video Store >> You are in a video store called Brickbuster Video. There are about 3,000 videos here. You can go north, or east.
# Action selected: north
# Total score after step: 50
#
# Iteration 42
# State: << Backroom >> You are in the backroom of Brickbuster Video. You see a small video on the floor, but you dismiss it as having no potential value to the crime. You can go south.
# Action selected: south
# Total score after step: 50
#
# Iteration 43
# State: << Video Store >> You are in a video store called Brickbuster Video. There are about 3,000 videos here. You can go north, or east.
# Action selected: east
# Total score after step: 60
#
# Iteration 44
# State: << Video Store >> You are still in the video store. You can go north, or east.  [Your score has just gone up by ten points.]
# Action selected: north
# Total score after step: 60
#
# Iteration 45
# State: << Closet >> You are in a closet. There is no use for being here. Gotta go south.
# Action selected: north
# Total score after step: 60
#
# Iteration 46
# State: You can't go north from here!  << Closet >> You are in a closet. There is no use for being here. Gotta go south.
# Action selected: north
# Total score after step: 60
#
# Iteration 47
# State: You can't go north from here!  << Closet >> You are in a closet. There is no use for being here. Gotta go south.
# Action selected: north
# Total score after step: 60
#
# Iteration 48
# State: You can't go north from here!  << Closet >> You are in a closet. There is no use for being here. Gotta go south.
# Action selected: north
# Total score after step: 60
#
# Iteration 49
# State: You can't go north from here!  << Closet >> You are in a closet. There is no use for being here. Gotta go south.
# Action selected: north
# Total score after step: 60
#
# Iteration 50
# State: You can't go north from here!  << Closet >> You are in a closet. There is no use for being here. Gotta go south.
# Action selected: north
# Total score after step: 60
#
# Iteration 51
# State: You can't go north from here!  << Closet >> You are in a closet. There is no use for being here. Gotta go south.
# Action selected: north
# Total score after step: 60
#
# Iteration 52
# State: You can't go north from here!  << Closet >> You are in a closet. There is no use for being here. Gotta go south.
# Action selected: north
# Total score after step: 60
#
# Iteration 53
# State: You can't go north from here!  << Closet >> You are in a closet. There is no use for being here. Gotta go south.
# Action selected: south
# Total score after step: 60
#
# Iteration 54
# State: << Video Store >> You are still in the video store. You can go north, or east.
# Action selected: west
# Total score after step: 60
#
# Iteration 55
# State: You can't go west from here!  << Video Store >> You are still in the video store. You can go north, or east.
# Action selected: east
# Total score after step: 60
#
# Iteration 56
# State: << Outside >> You are outside. You can go north, south, east or west.
# Action selected: west
# Total score after step: 60
#
# Iteration 57
# State: << Video Store >> You are still in the video store. You can go north, or east.
# Action selected: east
# Total score after step: 60
#
# Iteration 58
# State: << Outside >> You are outside. You can go north, south, east or west.
# Action selected: north
# Total score after step: 70
#
# Iteration 59
# State: << Outside >> You are still outside. You hit a dead end, then notice that you can go east only.  [Your score has just gone up by ten points.]
# Action selected: east
# Total score after step: 80
#
# Iteration 60
# State: << Music Store >> You are in a music store. You ask the man behind the counter if he knew any information. "Uhh... nope! But the guy back there might be able ta help." You politly thank him and head to the back. You can only go north.  [Your score has just gone up by ten points.]
# Action selected: north
# Total score after step: 90
#
# Iteration 61
# State: << Back of Music Store >> You are in the back of the music store. You ask the guy who's looking at the cool tapes. He looks up at you. "Duh.. no... don't t'ink so... lemme see..." You decide that he's no help. To the west there is a dazed looking man and to the north there is an exit.  [Your score has just gone up by ten points.]
# Action selected: west
# Total score after step: 90
#
# Iteration 62
# State: << Music Store >> You walk over to the guy. He jumps up with a wild look, and says "Freeze!". You stop. He motions you to the exit. But you know he'll probably just kill you. You NEED to get the weapon from him or kill him. Best chance: use your gun.  You can see a dazed man here. The dazed man seems to be getting angrier!
# Action selected: n
# Total score after step: 90
#
# Iteration 63
# State: The dazed man blocks your way! The dazed man seems to be getting angrier!
# Action selected: e
# Total score after step: 90
#
# Iteration 64
# State: The dazed man blocks your way! The dazed man seems to be getting angrier!
# Action selected: s
# Total score after step: 90
#
# Iteration 65
# State: The dazed man blocks your way! The dazed man seems to be getting angrier!
# Action selected: e
# Total score after step: 90
#
# Iteration 66
# State: The dazed man blocks your way! The dazed man seems to be getting angrier!
# Action selected: e
# Total score after step: 90
# 90

# %%
print(f'Final score in random playthrough: {agent.game.get_score()}')
# Out:
# Final score in random playthrough: 90

# %% [markdown]
# ## Training with Q-learning
#
# Hyperparameters used in the Q-learning implementation were:
# - $\epsilon$ = 0.1: The proportion of times the agent selects a random action (exploration) over the best/highest value action (exploitation); explore a fair amount of the time but not too much
# - $\alpha$ = 1: Learning rate; update a Q(s,a) value entirely rather than taking a weighted average of previous and new value
# - $\gamma$ = 0.999: Discount factor on future rewards; treat current and future rewards almost the same
#
#
# Let's calculate baseline performance by simulating random play for 1000 iterations and considering its average performance.

# %%
baseline = demo_n_games(agent, 1000, 'random')
baseline
# Out:
# 62.48

# %% [markdown]
# Now, let's see the agent's performance when learning the game over **10, 100, 1000, and 10,000 iterations** to compare their performance to the baseline and to each other.
#
# **10 iterations:**

# %%
agent.learn_game(10, 1)

qlearn_10iter = demo_n_games(agent, 1000, 'agent')
qlearn_10iter
# Out:
# Game #1 final score: 70
# Game #2 final score: 60
# Game #3 final score: 120
# Game #4 final score: 60
# Game #5 final score: 60
# Game #6 final score: 70
# Game #7 final score: 90
# Game #8 final score: 70
# Game #9 final score: 180
# Game #10 final score: 220
# 152.76

# %% [markdown]
# **100 iterations:**

# %%
agent.learn_game(100, 10)

qlearn_100iter = demo_n_games(agent, 1000, 'agent')
qlearn_100iter
# Out:
# Game #10 final score: 30
# Game #20 final score: 160
# Game #30 final score: 70
# Game #40 final score: 310
# Game #50 final score: 290
# Game #60 final score: 290
# Game #70 final score: 90
# Game #80 final score: 320
# Game #90 final score: 100
# Game #100 final score: 50
# 216.82

# %% [markdown]
# **1000 iterations:**

# %%
agent.learn_game(1000, 100)

qlearn_1000iter = demo_n_games(agent, 1000, 'agent')
qlearn_1000iter
# Out:
# Game #100 final score: 70
# Game #200 final score: 300
# Game #300 final score: 300
# Game #400 final score: 320
# Game #500 final score: 330
# Game #600 final score: 60
# Game #700 final score: 60
# Game #800 final score: 180
# Game #900 final score: 60
# Game #1000 final score: 120
# 225.81

# %% [markdown]
# **10000 iterations:**

# %%
agent.learn_game(10_000, 1000)

qlearn_10000iter = demo_n_games(agent, 1000, 'agent')
qlearn_10000iter
# Out:
# Game #1000 final score: 60
# Game #2000 final score: 90
# Game #3000 final score: 30
# Game #4000 final score: 80
# Game #5000 final score: 310
# Game #6000 final score: 330
# Game #7000 final score: 300
# Game #8000 final score: 40
# Game #9000 final score: 290
# Game #10000 final score: 80
# 227.19

# %% [markdown]
# ## Results and interpretation
#
# Here is a graphical comparison of the performance of

# %% [markdown]
# **Interpretation of results:**
# - Q-learning is unstable, as expected, as you can see from the high variance in scores in the training printouts
# - Increase in performance starts tapering off at as early as 100 episodes of training. This makes sense because the story of Detective is fairly simple, and there aren't that many "branches" of the story that are heavily dependent on any particular state (e.g. it is possible to get back to a main hallway after exploring a room).
# - Since Q-learning saves the reward associated with each state-action combination seen in a Q-table, the agent is effectively learning by exploring the graph structure of the story. Since Detective is relatively simple, the agent can learn to do well simply by exaustively exploring all the states in the game.

# %% [markdown]
# ## Extensions and lessons learned
#
# **Extensions**
# - Tune Q-learning hyperparameters more; try different rates of exploration, etc.
# - Try training my agent on other, more complex interactive fiction stories. I wrote my agent to be able to be generalized to other Jericho-compatible stories, so it should be possible.
# - Try deep Q-learning (DQN) and other reinforcement learning algorithms.
#
# **Lessons learned**
# - Interactive fiction is a unique problem with unique challenges! It requires a model that can accomodate that
# - Memoize for performance! Since FrotzEnv's `get_valid_actions()` method required natural language processing (NLP), it was a computationally expensive function, and I minimized calls to it by caching the valid actions for a given state the first time I make a `get_valid_actions()` call on that state.
# - Adapting a problem to a custom environment based on [OpenAI's Gym environment](https://gym.openai.com/) can be difficult, especially for an environment where the states are text and not numerical input. I attempted to write a [custom environment for Stable Baselines](https://stable-baselines.readthedocs.io/en/master/guide/custom_env.html) in order to apply their [prebuilt reinforcement learning algorithms](https://github.com/hill-a/stable-baselines).

# %% [markdown]
# ## Conclusion
